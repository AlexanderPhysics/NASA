# %% [markdown]
# ##Read and Show Sample Images

# %%
from astropy.io import fits

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###Load 4.2 MB Image

# %%
path = "/Users/Alexander/NASA/NASA_Sample_Data/fd_M_96m_01d.6543.0000.fits"

# %%
hdulist = fits.open(path)

# %%
type(hdulist)
# Out:
# astropy.io.fits.hdu.hdulist.HDUList

# %%
# meta-data of image 
hdulist.info()
# Out:
# Filename: /Users/Alexander/NASA/NASA_Sample_Data/fd_M_96m_01d.6543.0000.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     182   (1024, 1024)   float32

# %%
# refer to hud number 0 
hdu = hdulist[0]

# %%
# hdu has numpy array and dictionary methods
# let's treat it as an array
hdu.data.shape
# Out:
# (1024, 1024)

# %%
# view header
hdu.header
# Out:
# SIMPLE  =                    T / file conforms with FITS standard; SOI V6R1B0
# BITPIX  =                  -32
# NAXIS   =                    2
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# COMMENT Data from the Solar Oscillations Investigation / Michelson Doppler
# COMMENT   Imager (SOI/MDI) on the Solar and Heliospheric Observatory (SOHO).
# COMMENT For information on data rights, keyword definitions, and up-to-date
# COMMENT   reports on known problems and data quality, see:
# COMMENT   http://soi.stanford.edu/data.html
# HISTORY created by mdical Mon Dec  6 15:59:51 2010
# HISTORY created by MDI_image_reconstructor Thu Dec  9 10:03:53 2010
# HISTORY An MDI magnetogram zero level correction of 0.3709 Gauss
# HISTORY was subtracted from the level 1.5 input image.
# DSNAME  = 'prog:mdi,level:lev1.8,series:fd_M_96m_01d[6543]'
# PROTOCOL= 'RDB.FITS'
# DSDS_UID=                    0
# CONFORMS= 'TS_EQ   ' / SOI Conforming Dataset
# DATAKIND= 'NOT SPECIFIED'
# T_BLOCK = '1day    '
# T_STEP  = '96m     '
# T_START = '2010.12.01_00:00:00_TAI'
# T_STOP  = '2010.12.02_00:00:00_TAI'
# T_EPOCH = '1993.01.01_00:00:00_TAI'
# D_VARS  =                    1
# DUNIT0  = '        '
# DSIGN0  =                    1
# D_MIN0  =  -1.246255981445E+03
# D_MAX0  =   1.136079956055E+03
# D_MEAN0 =  -4.324637120794E-02
# D_RMS0  =   1.953480771070E+01
# DVALS0  =             11970300
# DNOTE0  = '        '
# RUNTIME = '2010.12.09_18:03:01_UT'
# XY_QUAL =                    0
# EPH_QUAL=                    0
# T_FIRST = '2010.11.30_23:59:30_TAI'
# T_LAST  = '2010.12.01_22:27:30_TAI'
# VDS_VERS= '2003.11.18'
# DATE    = '2010-12-09'
# CADENCE = '96m     '
# TELESCOP= 'SOHO    '
# INSTRUME= 'MDI     '
# SITE    = 'md      '
# PIXLENX =   1.000000000000E+00
# PIXLENY =   1.000000000000E+00
# DNAME0  = 'fd_M_96m'
# DFNAME0 = '%04d    '
# SOURCE  = 'prog:mdi,level:lev1.5[1],series:fd_M_96m_01d[6543]'
# SRC_ADJ = '/PDS22/D19109218/lev1.8_adj/tables/scale_corrections'
# I_DREC  =                98145
# DATAFILE= 'fd_M_96m_01d.6543.0000.fits'
# T_REC   = '2010.12.01_00:00:00_TAI'
# T_OBS   = '2010.11.30_23:59:30_TAI'
# BLDVER00=                60100
# BLDVER10=                60100
# CALTBLS = 'NONE    '
# QUALITY = '0x00000200'
# DATANAME= '        '
# DPC     = '0x48470FC0'
# DPC_STR = '0x48470FC0'
# DPC_OBSR= 'FD_Magnetogram'
# DPC_FORM= 'Cropped '
# DPC_CROP=   5.040000000000E+02
# DPC_ORGN= 'Space   '
# DPC_RATE= 'High-Rate'
# DPC_SMPL= '30 second'
# DPC_CONF=                    T
# SQID    = '0xc6940ad9'
# T_REF   = '2010.11.30_23:59:00_TAI'
# T_EARTH = '2010.11.30_23:59:34_TAI'
# MDIREF  = '        '
# BUNIT   = 'Gauss   '
# DATASIGN=                    1
# INTERVAL=   3.000000000000E+01
# IM_SCALE=   1.985686254244E+00 / original resolution, arc-sec / CCD pixel
# S_MAJOR =   1.000000000000E+00 / relative scale along semi-major axis
# S_MINOR =   1.000000000000E+00 / relative scale along semi-minor axis
# S_ANGLE =   0.000000000000E+00 / semi-major axis position angle from y (deg)
# MAGNIFY =   1.000000000000E+00 / magnification w.r.t. full-disc mode
# HR_MAG  =   3.267000000000E+00 / nominal magnification, HR mode / FD mode
# FD_SCALE=   1.985686254244E+00 / FD mode resolution, arc-sec/CCD pxl (nominal)
# PLATE_X =   5.115000000000E+02 / img ctr abscissa, pxl units from ctr col 0
# PLATE_Y =   5.115000000000E+02 / img ctr ordinate, pxl units from ctr row 0
# XSCALE  =   1.985686254244E+00 / arc-sec per image pixel (X)
# YSCALE  =   1.985686254244E+00 / arc-sec per image pixel (Y)
# X_SCALE =                    1 / CCD columns per image pixel
# Y_SCALE =                    1 / CCD rows per image pixel
# X_OPAXIS=   0.000000000000E+00 / optical axis (X) w.r.t. full-disc mode
# Y_OPAXIS=   0.000000000000E+00 / optical axis (Y) w.r.t. full-disc mode
# X_OFFSET=                    0
# Y_OFFSET=                    0
# XCEN    =   6.330389739986E-02
# YCEN    =   9.165446649170E-01
# DATAMIN =  -1.988285156250E+03
# DATAMAX =   1.846162841797E+03
# DATA_RMS=   3.768506174629E+01
# DATAMEAN=  -1.784817039704E-01
# DATAMEDN=   1.225416193963E+00
# DATASKEW=  -3.081319479751E+00
# DATAKURT=   5.068168431071E+02
# DATAVALS=               768311
# MISSVALS=                    0
# MISSPKTS=                    0
# CMPERRS =                    0
# SIZERRS =                    0
# EARTH_B0=   9.106809190215E-01
# EARTH_L0=   3.036978753527E+02
# EARTH_CR=                 2104
# EARTH_D =   9.861794626593E-01
# EARTH_VR=  -2.711914764916E+02
# EARTH_VW=   2.996656119018E+04
# EARTH_VN=  -3.783017028322E+03
# EARTH_R0=   9.730936033358E+02
# OBS_B0  =   9.452918835630E-01
# OBS_L0  =   3.034509292649E+02
# OBS_CR  =                 2104
# OBS_DIST=   9.772427248894E-01
# OBS_VR  =  -3.556187725888E+02
# OBS_VW  =   2.962040919331E+04
# OBS_VN  =  -3.784093593119E+03
# OBS_R0  =   9.819924649411E+02
# EARTH_DT=   4.459474898827E+00
# XY_FROM = 'SMOOTH  '
# MDI_X0  =   5.114679934184E+02
# MDI_Y0  =   5.110365931193E+02
# TBLXYUPD= '2010.12.08_18:42:43_TAI'
# ROLL_TBL= '/CM/tables/ephemeris/mdi_roll.smooth'
# ROLL_UPD= '2010.11.03_21:53:12_TAI'
# X0      =   5.114679934184E+02
# CENTER_X=   5.124679934184E+02
# CRPIX1  =   5.124679934184E+02
# CDELT1  =   1.985686254244E+00
# CTYPE1  = 'solar-x '
# Y0      =   5.110365931193E+02
# CENTER_Y=   5.120365931193E+02
# CRPIX2  =   5.120365931193E+02
# CDELT2  =   1.985686254244E+00
# CTYPE2  = 'solar-y '
# R_SUN   =   4.945355606116E+02
# SOLAR_P =  -1.728094755489E+02
# ORIGIN  = 'SOI Science Support Center'
# OBT_TIME=   1.669852740000E+09
# SOLAR_P0=  -1.728094755489E+02
# SOLAR_B0=   9.452918835630E-01
# OBS_TYPE= 'MAGNI   '
# DTYPE   = 'B       '
# OBS_MODE= 'FD_Magnetogram'
# ITIME   =   0.000000000000E+00
# B0      =   9.452918835630E-01
# L0      =   3.034509292649E+02
# P_ANGLE =  -1.728094755489E+02
# SEMIDIAM=   4.760833818586E-03
# VCOR1   =  -3.556187725888E+02
# FNDLMBXC=   5.124679934184E+02
# FNDLMBYC=   5.120365931193E+02
# FNDLMBMA=   4.964974239277E+02
# FNDLMBMI=   4.964974239277E+02
# FNDLMBAN=   0.000000000000E+00
# BLDVER15=                60100
# DATE-OBS= '2010/11/30'
# TIME-OBS= '23:59:01.46'
# DATE_OBS= '2010-11-30T23:59:01.459Z'
# ABS_MIN =   9.357551932335E-01
# BFITZERO=   0.000000000000E+00
# NPIXFLUX=               768311
# TOT_FLUX=   1.597569292253E+07
# AVG_FLUX=   2.079326330422E+01
# MEAN_FLD=  -1.784817039704E-01
# ORIENT  = 'SESW    '
# FDSCALEQ=                    1 / nominal, uncorrected
# BLDVER18=                60102
# BFITZORG=   3.708754090326E-01
# BFITZADJ=                    1
# SENSADJ =                    1
# SRC_ADJ2= '/PDS22/D19109218/lev1.8_adj/tables/ulrich2008scale_sinrho.fits'
# SINRHOVR= 'Ulrich 2008Version' / Sensitivity Correction
# NOTE1   = 'Lev 1.8.2 created by fdmagcal on Thu Dec  9 10:04:06 2010.'
# NOTE2   = 'Magnetic Flat Field Correction per Ulrich et al. 2008.'
# SPIKECNT=                    0
# SPIKETHR=      -5.00000000E+03
# SPIKEVER=       1.00000000E+00

# %% [markdown]
# ###Identify relevent features

# %%
# P_ANGLE = Angular location of the solar north pole on the image after mappings have been performed
print "P_ANGLE = {}".format(hdu.header["P_ANGLE"])
# OBS_B0 = Heliographic Latitude of the observer's disk center
print "B_ANGLE = {}".format(hdu.header["OBS_B0"])
# Sun-center as observed from Earth
print "(CENTER_X, CENTER_Y) = ({0}, {1})".format(hdu.header["CENTER_X"],hdu.header["CENTER_Y"])
# EARTH_R0 = Radius of the Sun in arc seconds, as viewed from earth.
print "Solar_Radius = {}".format(hdu.header["EARTH_R0"])
# Out:
# P_ANGLE = -172.809475549
# B_ANGLE = 0.945291883563
# (CENTER_X, CENTER_Y) = (512.467993418, 512.036593119)
# Solar_Radius = 973.093603336

# %%
plt.figure(figsize = (15,8));
plt.imshow(hdu.data, origin='lower');
plt.title("Solar Disk Image")
plt.show()

# %%
plt.figure(figsize = (10,8));
plt.imshow(hdu.data, origin='lower');
plt.ylim((340,410))
plt.xlim((270,380))
plt.title("Binary Sunspot ")
plt.show()

# %% [markdown]
# ###Load 67.1 MB Image

# %%
path2 = "/Users/Alexander/NASA/NASA_Sample_Data/HMI.m2010.12.01_00.00.00.fits"

# %%
hdulist2 = fits.open(path2)

# %%
# meta-data of image 
hdulist2.info()
# Out:
# Filename: /Users/Alexander/NASA/NASA_Sample_Data/HMI.m2010.12.01_00.00.00.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       8   ()
# 1                ImageHDU       100   (4096, 4096)   int32 (rescales to float64)

# %%
# David mentioned that the larger file would be nested
# refer to hud number 0 
hdu_2 = hdulist2[1]

# %%
hdu_2.data.shape
# Out:
# (4096, 4096)

# %%
# view header
hdu_2.header
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: Card 'SOURCE' is not FITS standard (invalid value string: "'hmi.lev1[:#6231403,#6149311,#6149239,#6149155,#6149083,#6149011,#6231").  Fixed 'SOURCE' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'SOURCE' is not FITS standard (invalid value string: "'hmi.lev1[:#6231403,#6149311,#6149239,#6149155,#6149083,#6149011,#6231").  Fixed 'SOURCE' card to meet the FITS standard.
# WARNING: VerifyWarning: Note: PyFITS uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Note: PyFITS uses zero-based indexing.
#
# WARNING: VerifyWarning: Card 'CRDER1' is not FITS standard (invalid value string: 'nan').  Fixed 'CRDER1' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'CRDER1' is not FITS standard (invalid value string: 'nan').  Fixed 'CRDER1' card to meet the FITS standard.
# WARNING: VerifyWarning: Card 'CRDER2' is not FITS standard (invalid value string: 'nan').  Fixed 'CRDER2' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'CRDER2' is not FITS standard (invalid value string: 'nan').  Fixed 'CRDER2' card to meet the FITS standard.
# WARNING: VerifyWarning: Card 'CSYSER1' is not FITS standard (invalid value string: 'nan').  Fixed 'CSYSER1' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'CSYSER1' is not FITS standard (invalid value string: 'nan').  Fixed 'CSYSER1' card to meet the FITS standard.
# WARNING: VerifyWarning: Card 'CSYSER2' is not FITS standard (invalid value string: 'nan').  Fixed 'CSYSER2' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'CSYSER2' is not FITS standard (invalid value string: 'nan').  Fixed 'CSYSER2' card to meet the FITS standard.
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -64 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                 4096 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# DATE    = '2010-12-11T02:56:52'
# DATE-OBS= '2010-11-30T23:58:11.60'
# TELESCOP= 'SDO/HMI'
# INSTRUME= 'HMI_SIDE1'
# WAVELNTH= 6173.0
# CAMERA  =                    1
# BUNIT   = 'Gauss'
# ORIGIN  = 'SDO/JSOC-SDP'
# CONTENT = 'MAGNETOGRAM'
# QUALITY =                    0
# QUALLEV1=                    0
# HISTORY Polynomial Coefficients used for Doppler velocity correction: 2.332614e+
# HISTORY 02 2.476129e-03 -3.268790e-07 1.489033e-10
# COMMENT De-rotation: ON; Un-distortion: ON; Re-centering: ON; Re-sizing: OFF; RS
# COMMENT UNerr=0.6; correction for cosmic-ray hits
# BLD_VERS= '-511'
# HCAMID  =                    2
# SOURCE  = '''hmi.lev1[:#6231403,#6149311,#6149239,#6149155,#6149083,#6149011,#&'
# CONTINUE  '6231'
# TOTVALS =             12312488
# DATAVALS=             12312488
# MISSVALS=                    0
# SATVALS =                10022
# DATAMIN2= -4477.107422
# DATAMAX2= 4477.107422
# DATAMED2= -0.003334
# DATAMEA2= 0.089062
# DATARMS2= 50.073227
# DATASKE2= 27.382450
# DATAKUR2= 5007.295898
# DATAMIN = -1548.389526
# DATAMAX = 1473.733521
# DATAMEDN= -0.016706
# DATAMEAN= -0.100556
# DATARMS = 24.677250
# DATASKEW= -3.240840
# DATAKURT= 968.198914
# CTYPE1  = 'HPLN-TAN'
# CTYPE2  = 'HPLT-TAN'
# CRPIX1  = 2039.290283
# CRPIX2  = 2046.418945
# CRVAL1  = 0.000000
# CRVAL2  = 0.000000
# CDELT1  = 0.504272
# CDELT2  = 0.504272
# CUNIT1  = 'arcsec'
# CUNIT2  = 'arcsec'
# CROTA2  = 180.082565
# CRDER1  = 'nan     '
# CRDER2  = 'nan     '
# CSYSER1 = 'nan     '
# CSYSER2 = 'nan     '
# WCSNAME = 'Helioprojective-cartesian'
# DSUN_OBS= 147530889520.71
# DSUN_REF= 149597870691
# RSUN_REF= 696000000
# CRLN_OBS= 303.771454
# CRLT_OBS= 0.918763
# CAR_ROT =                 2104
# OBS_VR  = 1875.772888
# OBS_VW  = 28782.302292
# OBS_VN  = -5627.121500
# RSUN_OBS= 973.090027
# T_OBS   = '2010.11.30_23:59:53_TAI'
# T_REC   = '2010.12.01_00:00:00_TAI'
# TRECEPOC= '1993.01.01_00:00:00_TAI'
# TRECSTEP= 720.0
# TRECUNIT= 'secs'
# CADENCE = 720.0
# DATASIGN=                    1
# HFLID   =                 1001
# HCFTID  =                   11
# QLOOK   =                    0
# CAL_FSN =              4875802
# LUTQUERY= 'hmi.lookup[4875802][][2][36][58][0][82]'
# TSEL    = 23.644638
# TFRONT  = 31.602398
# TINTNUM =                   10
# SINTNUM =                   10
# DISTCOEF= '/home/couvidat/cvs/JSOC/proj/lev1.5_hmi/apps/../libs/lev15/'
# ROTCOEF = '/home/couvidat/cvs/JSOC/proj/lev1.5_hmi/apps/../libs/lev15/'
# ODICOEFF=                    6
# OROCOEFF=                    4
# POLCALM =                    1
# CODEVER0= '$Id: HMI_IQUV_averaging.c,v 1.14 2010/11/20 00:59:40 couvidat Exp $'
# CODEVER1= '$Id: interpol_code.c,v 1.1 2010/09/16 20:46:48 couvidat Exp $'
# CODEVER2= '$Id: interpol_code.c,v 1.1 2010/09/16 20:46:48 couvidat Exp $'
# CODEVER3= '$Id: polcal.c,v 1.4 2010/09/23 20:57:27 schou Exp $'
# RECNUM  =                17682
# CHECKSUM= 'fZIOhX9MfXGMfX9M'   / HDU checksum updated 2012-07-23T16:27:29
# DATASUM = '19323598'           / data unit checksum updated 2012-07-23T16:27:29

# %%
import mpl_toolkits

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
# setup albers equal area conic basemap
# lat_1 is first standard parallel.
# lat_2 is second standard parallel.
# lon_0,lat_0 is central point.
m = Basemap(width=8000000,height=7000000,
            resolution='l',projection='aea',\
            lat_1=40.,lat_2=60,lon_0=35,lat_0=50)
m.drawcoastlines()
m.drawcountries()
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
m.drawparallels(np.arange(-80.,81.,20.))
m.drawmeridians(np.arange(-180.,181.,20.))
m.drawmapboundary(fill_color='aqua')
# draw tissot's indicatrix to show distortion.
ax = plt.gca()
for y in np.linspace(m.ymax/20,19*m.ymax/20,10):
    for x in np.linspace(m.xmax/20,19*m.xmax/20,12):
        lon, lat = m(x,y,inverse=True)
        poly = m.tissot(lon,lat,1.25,100,\
                        facecolor='green',zorder=10,alpha=0.5)
plt.title("Albers Equal Area Projection")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-80-0abbdca7fb4a> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 # setup albers equal area conic basemap
#       5 # lat_1 is first standard parallel.
#
# ImportError: No module named basemap
