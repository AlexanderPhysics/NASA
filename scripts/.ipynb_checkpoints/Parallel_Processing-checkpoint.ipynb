# %% [markdown]
# ##Parallel Pipeline
#     Proto-type the parallel pipeline -- from reading in the images to collecting the metrics.
#     Verify performance of pipeline, then deploy on Pleaides

# %% [markdown]
# ####Import Python Libraries

# %%
import matplotlib.pyplot as plt
from time import time, sleep
import numpy as np
import pandas as pd
import os
# %matplotlib inline

# %% [markdown]
# ####Import User Defined Libraries

# %%
def extract_metrics_only(image_path, metrics_path, file_name, mdi_flux_filter, hmi_flux_filter, kernal_std, num_pixel_in_active_region):
    '''
    This function is used to do a grid search in Parameter Space. 
    Because the same images need to be processed 10's or 100's of times, 
    it is not necessary (or wise) to save the image data to file. 
    The only data that should be saved is the metrics.

    For now, we are only processing MDI images.

    INPUT:  ...
    OUTPUT: ...
    
    '''

    image, hdu= extract_script.get_active_region_map(image_path, file_name,  mdi_flux_filter , hmi_flux_filter, kernal_std)
    labels = extract_script.get_active_region_labels(image)
    extract_results = extract_script.extract_features(labels,image, hdu, file_name, num_pixel_in_active_region)

    save_to_file([file_name,
                 (mdi_flux_filter, kernal_std, num_pixel_in_active_region),
                  extract_results], 
                  metrics_path, 
                  file_name)

# %% [markdown]
# ####Spin up Local Cluster

# %%
# To make sure that we are not running several clusters on the same host, 
# let's try to shut down any running IPython cluster first
# !ipcluster stop
# Out:
# 2016-03-02 14:19:39.455 [IPClusterStop] Stopping cluster [pid=3017] with [signal=2]

# %%
# start cluster with 'n' number of worker nodes
! ipcluster start -n=3 --daemon

# %%
# import the ipython parallel computing client 
from IPython.parallel import Client

# %%
client = Client()
print "There are currently {} nodes in the cluster".format(len(client))
# Out:
# There are currently 3 nodes in the cluster

# %% [markdown]
# ####Grid Search

# %%
image_path = "/Users/Alexander/NASA/NASA_Sample_Data/Images/"
filelist = []
for i, filename in enumerate(os.listdir(image_path)):
    if i != 0:
        filelist.append(filename)

# %%
lb_view = client.load_balanced_view()

# %%
# change path for Pleiades job
image_path = "/Users/Alexander/NASA/NASA_Sample_Data/Images/"
# WON'T be saving transformed image data to file
trans_image_path = "/Users/Alexander/NASA/trans_image_data_singleDay/"
# WON'T be saving extracted features to file 
feature_results_path = "/Users/Alexander/NASA/feature_extraction_results_singleDay/"
metrics_path = "/Users/Alexander/NASA/metrics_results/"

# %%
file_name_list = []
# MAY HAVE CHANGE THIS FOR PLEIADES
for filename in os.listdir(image_path):
    if "ds_store" not in filename.lower():
        file_name_list.append(filename)

# %%
# process images that are sufficiently differnt from each other
#test_index = np.arange(1, 400, 50) # used for diverse image sub-smaple
test_index = range(0,3)     
print "getting test_files for single day..."
test_files = [ file_name_list[index] for index in test_index]
# Out:
# getting test_files for single day...

# %%
test_files
# Out:
# ['fd_M_96m_01d.3925.0000.fits',
#  'fd_M_96m_01d.3925.0001.fits',
#  'fd_M_96m_01d.3925.0002.fits']

# %%
# PYTHONPATHs -- locations that python searches for importing packages
! python -c "import sys; print '\n'.join(x for x in sys.path if x)"
# Out:
# /Users/Alexander/spark-1.6.0-bin-hadoop2.4/python
# /Users/Alexander/NASA
# //anaconda/lib/python27.zip
# //anaconda/lib/python2.7
# //anaconda/lib/python2.7/plat-darwin
# //anaconda/lib/python2.7/plat-mac
# //anaconda/lib/python2.7/plat-mac/lib-scriptpackages
# //anaconda/lib/python2.7/lib-tk
# //anaconda/lib/python2.7/lib-old
# //anaconda/lib/python2.7/lib-dynload
# //anaconda/lib/python2.7/site-packages
# //anaconda/lib/python2.7/site-packages/PIL
# //anaconda/lib/python2.7/site-packages/Sphinx-1.2.3-py2.7.egg
# //anaconda/lib/python2.7/site-packages/runipy-0.1.1-py2.7.egg
# //anaconda/lib/python2.7/site-packages/setuptools-19.2-py2.7.egg

# %%
rc = Client()
dview = rc[:]

# %%
with dview.sync_imports():
    import sys
    sys.path[:] = ['/Users/Alexander/NASA/scripts/']

def parallel(x):
    import sys
    sys.path.insert(0, "/Users/Alexander/NASA/scripts")
    return sys.path

print 'Local: ', sys.path
print 'Remote: ', dview.map_sync(parallel, range(1))
# Out:
# Local:  ['/Users/Alexander/NASA/scripts/']
# Remote:  [['/Users/Alexander/NASA/scripts', '/Users/Alexander/NASA/scripts/', '', '', '', '/Users/Alexander/spark-1.6.0-bin-hadoop2.4/python', '/Users/Alexander', '//anaconda/lib/python27.zip', '//anaconda/lib/python2.7', '//anaconda/lib/python2.7/plat-darwin', '//anaconda/lib/python2.7/plat-mac', '//anaconda/lib/python2.7/plat-mac/lib-scriptpackages', '//anaconda/lib/python2.7/lib-tk', '//anaconda/lib/python2.7/lib-old', '//anaconda/lib/python2.7/lib-dynload', '/anaconda/lib/python2.7/site-packages/runipy-0.1.1-py2.7.egg', '/anaconda/lib/python2.7/site-packages/setuptools-19.2-py2.7.egg', '//anaconda/lib/python2.7/site-packages', '//anaconda/lib/python2.7/site-packages/PIL', '//anaconda/lib/python2.7/site-packages/Sphinx-1.2.3-py2.7.egg', '//anaconda/lib/python2.7/site-packages/IPython/extensions']]

# %%
# moving extract_features_scripts to site-packages in the python path did not work ....
# try something else

# %%
# import needed libraries to all engines being used 
with dview.sync_imports():
    import extract_features_scripts
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-3de838f97707> in <module>()
#       1 # import needed libraries to all engines being used
#       2 with dview.sync_imports():
# ----> 3     import extract_features_scripts
#
# //anaconda/lib/python2.7/site-packages/IPython/parallel/client/view.pyc in view_import(name, globals, locals, fromlist, level)
#     457                 # this is a side-effect import, don't do it remotely, or even
#     458                 # ignore the local effects
# --> 459                 return local_import(name, globals, locals, fromlist, level)
#     460
#     461             imp.acquire_lock()
#
# ImportError: No module named extract_features_scripts

# %%
task_list = []
for i, file_ in enumerate(test_files):
    start = time()
    # include parameter values for tunning
    task = dview.apply_async(extract_features_scripts.extract_features_from_images, 
                        image_path,
                        trans_image_path,
                        feature_results_path, 
                        file_)
    
    task_list.append(task.get())
    end = time()
    print "TIME ELAPSED {0} mins, IMAGE DONE {1}".format((end - start)/60.0, i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-829866c96b02> in <module>()
#       4     start = time()
#       5     # include parameter values for tunning
# ----> 6     task = dview.apply_async(extract_features_scripts.extract_features_from_images,
#       7                         image_path,
#       8                         trans_image_path,
#
# NameError: name 'extract_features_scripts' is not defined

# %%
task_results[0].get()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-c4b5f84de690> in <module>()
# ----> 1 task_results[0].get()
#
# IndexError: list index out of range

# %%
task_for_params = []
for filename in filelist[0:7]:  
    t = lb_view.apply(extscript.extract_features_from_images, 
                      image_path, 
                      filename)
    task_for_params.append(t)

# %%
import numpy as np
import pandas as pd

# %%
lst = np.array([1,2,3,4,5])

# %%
test_df = pd.DataFrame(lst)

# %%
test_df.to_csv
